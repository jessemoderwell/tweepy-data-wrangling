# %%
import sqlite3
import pandas as pd
import numpy as np

# %% [markdown]
# ## Convert csv to SQL database

# %%
df = pd.read_csv('twitter_archive_master.csv')

# %%
conn = sqlite3.connect('database.db')
c = conn.cursor()

# %%
df.to_sql("dog_tweets", conn, index=False)

# %%
df.head()
# Out:
#              tweet_id            timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56
# 1  892177421306343426  2017-08-01 00:17:27
# 2  891815181378084864  2017-07-31 00:18:03
# 3  891689557279858688  2017-07-30 15:58:51
# 4  891327558926688256  2017-07-29 16:00:24
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
#                                        expanded_urls      name  doggo  \
# 0  https://twitter.com/dog_rates/status/892420643...   Phineas  False
# 1  https://twitter.com/dog_rates/status/892177421...     Tilly  False
# 2  https://twitter.com/dog_rates/status/891815181...    Archie  False
# 3  https://twitter.com/dog_rates/status/891689557...     Darla  False
# 4  https://twitter.com/dog_rates/status/891327558...  Franklin  False
#
#    floofer  pupper  puppo  retweet_count  favorite_count  \
# 0    False   False  False           8853           39467
# 1    False   False  False           6514           33819
# 2    False   False  False           4328           25461
# 3    False   False  False           8964           42908
# 4    False   False  False           9774           41048
#
#                                            jpg_url                pred  conf  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg                 NaN   NaN
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg           Chihuahua  0.32
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg           Chihuahua  0.72
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg  Labrador_retriever  0.17
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg              basset  0.56
#
#   rating dog_stage
# 0  13/10     doggo
# 1  13/10     doggo
# 2  12/10     doggo
# 3  13/10     doggo
# 4  12/10     doggo

# %%
dog_keywords = df[['doggo','puppo','pupper','floofer']]
dog_stage = dog_keywords.idxmax(1).to_frame('dog_stage')

# %%
dog_stage.dog_stage.value_counts()
# Out:
# doggo      1761
# pupper      203
# puppo        22
# floofer       7
# Name: dog_stage, dtype: int64

# %%
df.doggo.replace('None', '', inplace=True)
df.floofer.replace('None', '', inplace=True)
df.pupper.replace('None', '', inplace=True)
df.puppo.replace('None', '', inplace=True)

# merge into column
df['dog_stage'] = dog_stage.dog_stage

# %%
c.execute("""SELECT timestamp
FROM dog_tweets;""")
data = pd.DataFrame(c.fetchall())
data.columns = [x[0] for x in c.description]
data.head()
# Out:
#              timestamp
# 0  2017-08-01 16:23:56
# 1  2017-08-01 00:17:27
# 2  2017-07-31 00:18:03
# 3  2017-07-30 15:58:51
# 4  2017-07-29 16:00:24

# %% [markdown]
# ## Agreggate mean retweet count per dog_stage

# %%
c.execute("""SELECT dog_stage,
AVG(retweet_count) AS avg_retweet_count
FROM dog_tweets
GROUP BY dog_stage
ORDER BY avg_retweet_count DESC;""")
data = pd.DataFrame(c.fetchall())
data.columns = [x[0] for x in c.description]
data.head()
# Out:
#   dog_stage  avg_retweet_count
# 0     puppo        6473.954545
# 1   floofer        4968.714286
# 2     doggo        2758.793867
# 3    pupper        2363.581281

# %% [markdown]
# ## Use Subquery/ temporary table to aggregate total retweets per predicted breed, in descending order

# %%
c.execute(""" 
SELECT pred,
SUM(retweet_count) AS total_retweets
FROM (SELECT pred,
retweet_count
FROM dog_tweets) sub
GROUP BY pred
ORDER BY total_retweets DESC;""")
data = pd.DataFrame(c.fetchall())
data.columns = [x[0] for x in c.description]
data.head(25)
# Out:
#                          pred  total_retweets
# 0                        None          767245
# 1            golden_retriever          585873
# 2          Labrador_retriever          407573
# 3                    Pembroke          292052
# 4                   Chihuahua          251807
# 5                     Samoyed          203446
# 6              French_bulldog          156230
# 7              cocker_spaniel          145743
# 8                        chow          131025
# 9                         pug          118682
# 10                 toy_poodle          115768
# 11                 Pomeranian          112171
# 12                   malamute          102515
# 13                 Eskimo_dog           93183
# 14   Chesapeake_Bay_retriever           81730
# 15                   Cardigan           79765
# 16           Lakeland_terrier           73488
# 17             Great_Pyrenees           68008
# 18            standard_poodle           60598
# 19         miniature_pinscher           57728
# 20            German_shepherd           56205
# 21           English_springer           54016
# 22                    whippet           53243
# 23                     basset           49563
# 24  Staffordshire_bullterrier           48253

# %% [markdown]
# ## Use Window function to create running favorite_count minimum by month, in chronological order

# %%
c.execute(""" 
SELECT timestamp,
favorite_count,
MIN(favorite_count) OVER 
(PARTITION BY strftime('%M-%Y', timestamp) 
ORDER BY timestamp) AS monthly_min
FROM dog_tweets;""")
data = pd.DataFrame(c.fetchall())
data.columns = [x[0] for x in c.description]
data.head(25)
# Out:
#               timestamp  favorite_count  monthly_min
# 0   2015-11-17 02:00:15             170          170
# 1   2015-11-21 04:00:28             222          170
# 2   2015-11-26 01:00:28             375          170
# 3   2015-11-28 02:00:17            1415          170
# 4   2015-12-01 17:00:19            1534          170
# 5   2015-12-04 22:00:08             944          170
# 6   2015-12-05 04:00:04            1039          170
# 7   2015-12-18 04:00:46            3689          170
# 8   2015-12-24 16:00:30           18278          170
# 9   2015-12-24 17:00:27            2818          170
# 10  2015-12-24 18:00:19           13959          170
# 11  2015-12-24 19:00:23            3891          170
# 12  2015-12-24 20:00:22            2972          170
# 13  2015-12-24 21:00:12            2519          170
# 14  2015-12-24 22:00:10            3955          170
# 15  2015-12-24 23:00:17            2538          170
# 16  2015-12-25 00:00:11            4263          170
# 17  2015-12-25 01:00:07            2356          170
# 18  2015-12-25 03:00:14            1598          170
# 19  2015-12-26 03:00:19            3939          170
# 20  2015-12-28 23:00:52            2100          170
# 21  2015-12-30 01:00:03            3464          170
# 22  2016-01-01 05:00:24            2706         2706
# 23  2016-01-01 21:00:32            2370         2370
# 24  2016-01-05 01:00:50            2215         2215

# %% [markdown]
# ## Use Window function to create moving favorite_count average over last 90 tweets, in chronological order

# %%
c.execute(""" 
SELECT timestamp,
favorite_count,
AVG(favorite_count) OVER (ORDER BY timestamp ASC ROWS 90 PRECEDING) AS favorite_count_moving_average
FROM dog_tweets;""")
data = pd.DataFrame(c.fetchall())
data.columns = [x[0] for x in c.description]
data.head(25)
# Out:
#               timestamp  favorite_count  favorite_count_moving_average
# 0   2015-11-15 22:32:08            2535                    2535.000000
# 1   2015-11-15 23:05:30             132                    1333.500000
# 2   2015-11-15 23:21:54             128                     931.666667
# 3   2015-11-16 00:04:52             311                     776.500000
# 4   2015-11-16 00:24:50             111                     643.400000
# 5   2015-11-16 00:30:50             136                     558.833333
# 6   2015-11-16 00:35:11            1253                     658.000000
# 7   2015-11-16 00:49:46             448                     631.750000
# 8   2015-11-16 00:55:59             304                     595.333333
# 9   2015-11-16 01:01:59             115                     547.300000
# 10  2015-11-16 01:22:45             496                     542.636364
# 11  2015-11-16 01:52:02             154                     510.250000
# 12  2015-11-16 01:59:36             335                     496.769231
# 13  2015-11-16 02:38:37             121                     469.928571
# 14  2015-11-16 03:22:39             169                     449.866667
# 15  2015-11-16 03:44:34             164                     432.000000
# 16  2015-11-16 03:55:04              81                     411.352941
# 17  2015-11-16 04:02:55           14765                    1208.777778
# 18  2015-11-16 14:57:41             108                    1150.842105
# 19  2015-11-16 15:14:19             184                    1102.500000
# 20  2015-11-16 16:11:11             152                    1057.238095
# 21  2015-11-16 16:37:02             522                    1032.909091
# 22  2015-11-16 19:31:45             204                     996.869565
# 23  2015-11-16 20:01:42             307                     968.125000
# 24  2015-11-16 20:32:58             229                     938.560000
